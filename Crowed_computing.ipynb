# %%
from statistics import mean
print("CROWD COMPUTING")
print("****************")
Estimates = [200,100,250,375,300,500,800,900,200,100,600,90,250,300,350,363,397,450,500,700,275,125,185,225,240,310,415,300,250,300,2000,2500]
i = 0
for i in range(len(Estimates)):
    print(Estimates[i])
Estimates.sort()
print("SORTED VALUE")
for i in range(len(Estimates)):
    print(Estimates[i])
tv = int (0.1 * len(Estimates))
Estimates = Estimates[tv:len(Estimates)-tv]
print("COMPUTER VALUE")
for i in range(len(Estimates)):
    print(Estimates[i])
print("\t", mean(Estimates))
# Out:
# CROWD COMPUTING
# ****************
# 200
# 100
# 250
# 375
# 300
# 500
# 800
# 900
# 200
# 100
# 600
# 90
# 250
# 300
# 350
# 363
# 397
# 450
# 500
# 700
# 275
# 125
# 185
# 225
# 240
# 310
# 415
# 300
# 250
# 300
# 2000
# 2500
# SORTED VALUE
# 90
# 100
# 100
# 125
# 185
# 200
# 200
# 225
# 240
# 250
# 250
# 250
# 275
# 300
# 300
# 300
# 300
# 310
# 350
# 363
# 375
# 397
# 415
# 450
# 500
# 500
# 600
# 700
# 800
# 900
# 2000
# 2500
# COMPUTER VALUE
# 125
# 185
# 200
# 200
# 225
# 240
# 250
# 250
# 250
# 275
# 300
# 300
# 300
# 300
# 310
# 350
# 363
# 375
# 397
# 415
# 450
# 500
# 500
# 600
# 700
# 800
# 	 352.3076923076923
